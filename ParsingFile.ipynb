# %%
import pandas as pd

# %%
f = open('codon_usage.csv', 'r')
df = pd.read_csv(f)
# Out:
# C:\Users\mayam\AppData\Local\Temp\ipykernel_13036\141334434.py:2: DtypeWarning: Columns (5,6) have mixed types. Specify dtype option on import or set low_memory=False.
#   df = pd.read_csv(f)

# %%
rodents_mit = df[df['Kingdom'] == 'rod']

# %%
rodents = rodents_mit[rodents_mit['DNAtype'] == 0]

# %%
rodents
# Out:
#       Kingdom  DNAtype  SpeciesID   Ncodons                    SpeciesName  \
# 12633     rod        0      10007      3175                 Sciurus aberti
# 12636     rod        0      10013     13348                Thomomys bottae
# 12638     rod        0      10026      2833                     Cricetinae
# 12639     rod        0      10029    153527             Cricetulus griseus
# 12641     rod        0      10030     22059       Cricetulus longicaudatus
# 12642     rod        0      10031     11148                 Cricetulus sp.
# 12643     rod        0      10032      2223         Cricetulus migratorius
# 12644     rod        0      10034      4210              Cricetus cricetus
# 12645     rod        0      10036    141900           Mesocricetus auratus
# 12646     rod        0      10041      1400            Peromyscus leucopus
# 12647     rod        0      10042     38901         Peromyscus maniculatus
# ...
